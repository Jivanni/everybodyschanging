# %%
import re
import pandas as pd

# %%
df = pd.read_csv("final_df_unordered.csv", sep=";").drop_duplicates(subset="id")
# Out:
# /home/toccasana/anaconda3/envs/env_master/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (12,30) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#         original_song_name  original_artists_name  curr_rank tag_fimi  \
# 0    svegliarsi la mattina          zero assoluto          1      sgo
# 27                     one     mary j. blige & u2          2      uni
# 470         sei nell'anima         gianna nannini          3      uni
# 518            upside down           jack johnson          4      uni
# 534        dani california  red hot chili peppers          5      wmi
#
#     publisher  date_chart album_release_date   album_type  \
# 0         NaN  2006-05-07         2006-02-28       single
# 27        NaN  2006-05-07         2006-01-01  compilation
# 470       NaN  2006-05-07         2006-11-27        album
# 518       NaN  2006-05-07               2006        album
# 534       NaN  2006-05-07         2006-04-03       single
#
#                  song_name                album_id  ... valence    tempo  \
# 0    Svegliarsi la mattina  6d1AvZ3brZ9caD2cFbIbbd  ...  0.6070  171.970
# 27                     One  72jdJEV95RFo6oecTO5tVk  ...  0.0875  114.897
# 470         Sei nell'anima  2htq51kTRL2dwMxa2mBfJi  ...  0.4680   91.010
# 518            Upside Down  0kYv61g7n6ZPe2TVaIBeeJ  ...  0.6470  102.476
# 534        Dani California  3rrvHWzZCF8TvqT9oJtfVZ  ...  0.7300   96.184
#
#                type                      id  \
# 0    audio_features  1ecMdfIXNksJTymYlzsFZ3
# 27   audio_features  7nIWJew9BlYm5j0Bc9TUvr
# 470  audio_features  6shzlUkm7OcnoO4guEiGJ8
# 518  audio_features  3YOigAKOgFTQuLjF9MBmd3
# 534  audio_features  6vODhpvfWwdsO0i9MBWnEq
#
#                                                    uri  \
# 0    https://api.spotify.com/v1/tracks/1ecMdfIXNksJ...
# 27   https://api.spotify.com/v1/tracks/7nIWJew9BlYm...
# 470  https://api.spotify.com/v1/tracks/6shzlUkm7Ocn...
# 518  https://api.spotify.com/v1/tracks/3YOigAKOgFTQ...
# 534  https://api.spotify.com/v1/tracks/6vODhpvfWwds...
#
#                                             track_href  analysis_url  \
# 0    https://api.spotify.com/v1/audio-analysis/1ecM...        223053
# 27   https://api.spotify.com/v1/audio-analysis/7nIW...        255667
# 470  https://api.spotify.com/v1/audio-analysis/6shz...        270347
# 518  https://api.spotify.com/v1/audio-analysis/3YOi...        208653
# 534  https://api.spotify.com/v1/audio-analysis/6vOD...        282160
#
#      duration_ms  time_signature  song_id
# 0            4.0             NaN      NaN
# 27           4.0             NaN      NaN
# 470          4.0             NaN      NaN
# 518          4.0             NaN      NaN
# 534          4.0             NaN      NaN
#
# [5 rows x 34 columns]

# %%
song_unique = df[['id', 'tag_fimi',
       'publisher', 'album_release_date', 'album_type',
       'song_name', 'album_id', 'artists_names', 'artists_id', 'explicit',
       'duration', 'popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'type',
     'duration_ms']]

# %%
song_unique.head()
# Out:
#                          id tag_fimi publisher album_release_date  \
# 0    1ecMdfIXNksJTymYlzsFZ3      sgo       NaN         2006-02-28
# 27   7nIWJew9BlYm5j0Bc9TUvr      uni       NaN         2006-01-01
# 470  6shzlUkm7OcnoO4guEiGJ8      uni       NaN         2006-11-27
# 518  3YOigAKOgFTQuLjF9MBmd3      uni       NaN               2006
# 534  6vODhpvfWwdsO0i9MBWnEq      wmi       NaN         2006-04-03
#
#       album_type              song_name                album_id  \
# 0         single  Svegliarsi la mattina  6d1AvZ3brZ9caD2cFbIbbd
# 27   compilation                    One  72jdJEV95RFo6oecTO5tVk
# 470        album         Sei nell'anima  2htq51kTRL2dwMxa2mBfJi
# 518        album            Upside Down  0kYv61g7n6ZPe2TVaIBeeJ
# 534       single        Dani California  3rrvHWzZCF8TvqT9oJtfVZ
#
#                  artists_names                  artists_id explicit  ...  \
# 0            ['Zero Assoluto']  ['3bf7Y2it29DeOjXpIibCOe']    False  ...
# 27                      ['U2']  ['51Blml2LZPmy7TTiAg47vQ']    False  ...
# 470         ['Gianna Nannini']  ['0h0p7RkMjCUMdcf0nXmHjX']    False  ...
# 518           ['Jack Johnson']  ['3GBPw9NK25X1Wt2OUvOwY3']    False  ...
# 534  ['Red Hot Chili Peppers']  ['0L8ExT028jH3ddEcZwqJJ5']    False  ...
#
#      loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0      -9.350   1.0       0.0423       0.18100          0.000458    0.0737
# 27     -5.010   1.0       0.0335       0.00548          0.000012    0.6810
# 470    -5.704   1.0       0.0216       0.40400          0.000002    0.0834
# 518    -8.299   0.0       0.0433       0.22800          0.000128    0.1630
# 534    -2.360   1.0       0.0437       0.01930          0.000009    0.3460
#
#      valence    tempo            type  duration_ms
# 0     0.6070  171.970  audio_features          4.0
# 27    0.0875  114.897  audio_features          4.0
# 470   0.4680   91.010  audio_features          4.0
# 518   0.6470  102.476  audio_features          4.0
# 534   0.7300   96.184  audio_features          4.0
#
# [5 rows x 25 columns]

# %%
song_unique.to_csv("unique_songs_with_feats_4.csv",index=False, sep=";")

# %%
artists = df.drop_duplicates(subset="artists_names")["artists_names"].to_list()
out = []
for artist in artists:
    try:
        out.extend(eval(artist))
    except:
        out.append(artist)
#reg = re.compile(r",.+")
out_filtered = set([i for i in out])

# %%
song_unique.to_csv("unique_songs_FINALISSIMISSIMO_2006_2021.csv",index=False, sep=";")

# %%
pd.DataFrame(out_filtered, columns = ["artists_names"]).to_csv("unique_artists_4.csv",index=False)

# %%
import re
import pandas as pd

# %%
wiki = pd.read_csv("data/wikipages_it.csv", sep=";")

# %%
wikieng = pd.read_csv("data/wikipages_eng.csv", sep=";")

# %%
pd.merge(wiki,wikieng,on="spotyname", how="outer").to_csv("wikipages_eng_it_finale.csv",index=False, sep=";")

# %%
finalarts = pd.read_csv("data/pages/unique_artists_FINALISSIMISSIMO_2006_2021.csv", sep=";")

# %%
dwnpages = pd.read_csv("data/pages/wikipages_eng_it_full.csv",sep=";")

# %%
dwnpages.describe
# Out:
# <bound method NDFrame.describe of              spotyname            wikipagename           wikipagename_eng
# 0          Brunori Sas             Brunori Sas                Brunori Sas
# 1            Side Baby                     NaN                  Side Baby
# 2     Michael Marshall  Michael Marshall Smith  Michael Marshall (singer)
# 3     Michael Kiwanuka        Michael Kiwanuka           Michael Kiwanuka
# 4               Fergie                  Fergie            Fergie (singer)
# ...                ...                     ...                        ...
# 1959      Milky Chance            Milky Chance               Milky Chance
# 1960        Maty Noyes              Maty Noyes                 Maty Noyes
# 1961         21 Savage               21 Savage                  21 Savage
# 1962     David Gilmour           David Gilmour              David Gilmour
# 1963         Tom Jones    Tom Jones (cantante)         Tom Jones (singer)
#
# [1964 rows x 3 columns]>

# %%
finalarts.describe
# Out:
# <bound method NDFrame.describe of               spotyname
# 0            cmqmartina
# 1     Children Of Bodom
# 2               Ward 21
# 3              Maroon 5
# 4             Rammstein
# ...                 ...
# 2424       Samuel Storm
# 2425  Cast Of Camp Rock
# 2426              JAY-Z
# 2427              Jaden
# 2428      La Differenza
#
# [2429 rows x 1 columns]>

# %%
inter = dwnpages.merge(finalarts, how = 'outer')

# %%
inter.describe
# Out:
# <bound method NDFrame.describe of                spotyname            wikipagename           wikipagename_eng
# 0            Brunori Sas             Brunori Sas                Brunori Sas
# 1              Side Baby                     NaN                  Side Baby
# 2       Michael Marshall  Michael Marshall Smith  Michael Marshall (singer)
# 3       Michael Kiwanuka        Michael Kiwanuka           Michael Kiwanuka
# 4                 Fergie                  Fergie            Fergie (singer)
# ...                  ...                     ...                        ...
# 2436      Enrico Musiani                     NaN                        NaN
# 2437               Nabat                     NaN                        NaN
# 2438                ANNA                     NaN                        NaN
# 2439  Axwell /\ Ingrosso                     NaN                        NaN
# 2440               Morad                     NaN                        NaN
#
# [2441 rows x 3 columns]>

# %%
inter.merge(finalarts, how="inner").to_csv("wikipages_eng_it_complete.csv",index=False, sep=";")
