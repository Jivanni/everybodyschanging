# %%
import re
import pandas as pd

# %%
df = pd.read_csv("../../../data/combined_df_final.csv", sep=";")

# %%
df.to_csv("combined_df_final_nospace.csv", sep=";",index=False)

# %%
df.groupby("song_id").first()
# Out:
#                              original_song_name  \
# song_id
# 000xQL6tZNLJzIrtIgxqSl           still got time
# 004zGvrc84enQHFitC6auy  mercy on me (in sbatti)
# 005EC8njtQVvXhIgWajeMe                  bad day
# 006Ndmw2hHxvnLbJsBFnPx   nel blu dipinto di blu
# 009ImBOrIUlWgla8U05RAC          unconditionally
# ...                                         ...
# 7zivIUyCw9MmYftdcayXnN              uno squillo
# 7zkLpY72g6lKQbiHDqri1S                  sunrise
# 7zrHnJ87htwgS20PzFmgTr            radio nowhere
# 7ztN8tfXYaC8LBRyLZJLA1                limousine
# 7zuIcCFkiXq4iS0GUL7Mtr                 insolita
#
#                                           original_artists_name  curr_rank  \
# song_id
# 000xQL6tZNLJzIrtIgxqSl                 zayn feat. partynextdoor         70
# 004zGvrc84enQHFitC6auy                              guè pequeno         48
# 005EC8njtQVvXhIgWajeMe                            daniel powter         40
# 006Ndmw2hHxvnLbJsBFnPx                         domenico modugno         55
# 009ImBOrIUlWgla8U05RAC                               katy perry         86
# ...                                                         ...        ...
# 7zivIUyCw9MmYftdcayXnN                               capo plaza         39
# 7zkLpY72g6lKQbiHDqri1S                              norah jones         73
# 7zrHnJ87htwgS20PzFmgTr                        bruce springsteen         28
# 7ztN8tfXYaC8LBRyLZJLA1  enzo d.o.n.g. feat. tedua & chris nolan        100
# 7zuIcCFkiXq4iS0GUL7Mtr                            le vibrazioni         38
#
#                                                 tag_fimi publisher  \
# song_id
# 000xQL6tZNLJzIrtIgxqSl                          rca int.       sme
# 004zGvrc84enQHFitC6auy                            island       uni
# 005EC8njtQVvXhIgWajeMe                               wmi       wmi
# 006Ndmw2hHxvnLbJsBFnPx                               sme      None
# 009ImBOrIUlWgla8U05RAC                           capitol       uni
# ...                                                  ...       ...
# 7zivIUyCw9MmYftdcayXnN  plaza music/sto records/atlantic       wmi
# 7zkLpY72g6lKQbiHDqri1S                               emi      None
# 7zrHnJ87htwgS20PzFmgTr                               sbm       sbm
# 7ztN8tfXYaC8LBRyLZJLA1                         enzo dong   believe
# 7zuIcCFkiXq4iS0GUL7Mtr                               sbm      None
#
#                         date_chart album_release_date album_type  \
# song_id
# 000xQL6tZNLJzIrtIgxqSl  30.03.2017         2017-03-23     single
# 004zGvrc84enQHFitC6auy  02.07.2020         2020-06-25      album
# 005EC8njtQVvXhIgWajeMe  07.05.2006         2005-02-22      album
# 006Ndmw2hHxvnLbJsBFnPx  24.02.2013         2008-02-28      album
# 009ImBOrIUlWgla8U05RAC  27.10.2013         2013-01-01      album
# ...                            ...                ...        ...
# 7zivIUyCw9MmYftdcayXnN  26.04.2018         2018-04-20      album
# 7zkLpY72g6lKQbiHDqri1S  11.09.2011         2004-01-01      album
# 7zrHnJ87htwgS20PzFmgTr  14.10.2007         2007-09-25      album
# 7ztN8tfXYaC8LBRyLZJLA1  10.10.2019         2019-10-09     single
# 7zuIcCFkiXq4iS0GUL7Mtr  06.04.2008         2008-03-14     single
#
#                                                    song_name  \
# song_id
# 000xQL6tZNLJzIrtIgxqSl  Still Got Time (feat. PARTYNEXTDOOR)
# 004zGvrc84enQHFitC6auy               Mercy On Me (In Sbatti)
# 005EC8njtQVvXhIgWajeMe                               Bad Day
# 006Ndmw2hHxvnLbJsBFnPx                Nel blu dipinto di blu
# 009ImBOrIUlWgla8U05RAC                       Unconditionally
# ...                                                      ...
# 7zivIUyCw9MmYftdcayXnN                           Uno squillo
# 7zkLpY72g6lKQbiHDqri1S                               Sunrise
# 7zrHnJ87htwgS20PzFmgTr                         Radio Nowhere
# 7ztN8tfXYaC8LBRyLZJLA1                             Limousine
# 7zuIcCFkiXq4iS0GUL7Mtr                              Insolita
#
#                                       album_id  ... liveness valence    tempo  \
# song_id                                         ...
# 000xQL6tZNLJzIrtIgxqSl  2kGUeTGnkLOYlinKRJe47G  ...   0.0852   0.524  120.963
# 004zGvrc84enQHFitC6auy  7C9m0DdXdl0Z92bmv45BpX  ...   0.3210   0.584  172.040
# 005EC8njtQVvXhIgWajeMe  4zhigAhPwqp43XVHBiVeQI  ...   0.1000   0.349   92.032
# 006Ndmw2hHxvnLbJsBFnPx  3RWfLO5X2CSxBI5oH84mra  ...   0.1610   0.336  127.870
# 009ImBOrIUlWgla8U05RAC  3jB9yFDwRe3KhtGnHXJntk  ...   0.2080   0.353  128.902
# ...                                        ...  ...      ...     ...      ...
# 7zivIUyCw9MmYftdcayXnN  0KYX8LOknGNZ7CkC5EuHJw  ...   0.0736   0.679   98.970
# 7zkLpY72g6lKQbiHDqri1S  7GaAXgbFSpcJOiLlFGYyOL  ...   0.1060   0.679  156.848
# 7zrHnJ87htwgS20PzFmgTr  7A830iYFt7vb0n0aMLyj5Z  ...   0.3600   0.658  140.219
# 7ztN8tfXYaC8LBRyLZJLA1  1bSofQ0zLHVlETI66xgcLJ  ...   0.1270   0.724   74.776
# 7zuIcCFkiXq4iS0GUL7Mtr  5yD4WGIWMAuNLqC6cax7mJ  ...   0.1040   0.166  180.491
#
#                                   type                      id  \
# song_id
# 000xQL6tZNLJzIrtIgxqSl  audio_features  000xQL6tZNLJzIrtIgxqSl
# 004zGvrc84enQHFitC6auy  audio_features  004zGvrc84enQHFitC6auy
# 005EC8njtQVvXhIgWajeMe  audio_features  6uqeN1m6DXG0yOQ4WMNndB
# 006Ndmw2hHxvnLbJsBFnPx  audio_features  006Ndmw2hHxvnLbJsBFnPx
# 009ImBOrIUlWgla8U05RAC  audio_features  009ImBOrIUlWgla8U05RAC
# ...                                ...                     ...
# 7zivIUyCw9MmYftdcayXnN  audio_features  7zivIUyCw9MmYftdcayXnN
# 7zkLpY72g6lKQbiHDqri1S  audio_features  7zkLpY72g6lKQbiHDqri1S
# 7zrHnJ87htwgS20PzFmgTr  audio_features  7zrHnJ87htwgS20PzFmgTr
# 7ztN8tfXYaC8LBRyLZJLA1  audio_features  7ztN8tfXYaC8LBRyLZJLA1
# 7zuIcCFkiXq4iS0GUL7Mtr  audio_features  7zuIcCFkiXq4iS0GUL7Mtr
#
#                                                                       uri  \
# song_id
# 000xQL6tZNLJzIrtIgxqSl               spotify:track:000xQL6tZNLJzIrtIgxqSl
# 004zGvrc84enQHFitC6auy  https://api.spotify.com/v1/tracks/004zGvrc84en...
# 005EC8njtQVvXhIgWajeMe  https://api.spotify.com/v1/tracks/6uqeN1m6DXG0...
# 006Ndmw2hHxvnLbJsBFnPx               spotify:track:006Ndmw2hHxvnLbJsBFnPx
# 009ImBOrIUlWgla8U05RAC  https://api.spotify.com/v1/tracks/009ImBOrIUlW...
# ...                                                                   ...
# 7zivIUyCw9MmYftdcayXnN  https://api.spotify.com/v1/tracks/7zivIUyCw9Mm...
# 7zkLpY72g6lKQbiHDqri1S  https://api.spotify.com/v1/tracks/7zkLpY72g6lK...
# 7zrHnJ87htwgS20PzFmgTr  https://api.spotify.com/v1/tracks/7zrHnJ87htwg...
# 7ztN8tfXYaC8LBRyLZJLA1               spotify:track:7ztN8tfXYaC8LBRyLZJLA1
# 7zuIcCFkiXq4iS0GUL7Mtr  https://api.spotify.com/v1/tracks/7zuIcCFkiXq4...
#
#                                                                track_href  \
# song_id
# 000xQL6tZNLJzIrtIgxqSl  https://api.spotify.com/v1/tracks/000xQL6tZNLJ...
# 004zGvrc84enQHFitC6auy  https://api.spotify.com/v1/audio-analysis/004z...
# 005EC8njtQVvXhIgWajeMe  https://api.spotify.com/v1/audio-analysis/6uqe...
# 006Ndmw2hHxvnLbJsBFnPx  https://api.spotify.com/v1/tracks/006Ndmw2hHxv...
# 009ImBOrIUlWgla8U05RAC  https://api.spotify.com/v1/audio-analysis/009I...
# ...                                                                   ...
# 7zivIUyCw9MmYftdcayXnN  https://api.spotify.com/v1/audio-analysis/7ziv...
# 7zkLpY72g6lKQbiHDqri1S  https://api.spotify.com/v1/audio-analysis/7zkL...
# 7zrHnJ87htwgS20PzFmgTr  https://api.spotify.com/v1/audio-analysis/7zrH...
# 7ztN8tfXYaC8LBRyLZJLA1  https://api.spotify.com/v1/tracks/7ztN8tfXYaC8...
# 7zuIcCFkiXq4iS0GUL7Mtr  https://api.spotify.com/v1/audio-analysis/7zuI...
#
#                                                              analysis_url  \
# song_id
# 000xQL6tZNLJzIrtIgxqSl  https://api.spotify.com/v1/audio-analysis/000x...
# 004zGvrc84enQHFitC6auy                                             184186
# 005EC8njtQVvXhIgWajeMe                                             232412
# 006Ndmw2hHxvnLbJsBFnPx  https://api.spotify.com/v1/audio-analysis/006N...
# 009ImBOrIUlWgla8U05RAC                                             228879
# ...                                                                   ...
# 7zivIUyCw9MmYftdcayXnN                                             208813
# 7zkLpY72g6lKQbiHDqri1S                                             200627
# 7zrHnJ87htwgS20PzFmgTr                                             199067
# 7ztN8tfXYaC8LBRyLZJLA1  https://api.spotify.com/v1/audio-analysis/7ztN...
# 7zuIcCFkiXq4iS0GUL7Mtr                                             244373
#
#                         duration_ms  time_signature
# song_id
# 000xQL6tZNLJzIrtIgxqSl     188491.0             4.0
# 004zGvrc84enQHFitC6auy          4.0             NaN
# 005EC8njtQVvXhIgWajeMe          4.0             NaN
# 006Ndmw2hHxvnLbJsBFnPx     216373.0             4.0
# 009ImBOrIUlWgla8U05RAC          4.0             NaN
# ...                             ...             ...
# 7zivIUyCw9MmYftdcayXnN          4.0             NaN
# 7zkLpY72g6lKQbiHDqri1S          4.0             NaN
# 7zrHnJ87htwgS20PzFmgTr          4.0             NaN
# 7ztN8tfXYaC8LBRyLZJLA1     208074.0             4.0
# 7zuIcCFkiXq4iS0GUL7Mtr          4.0             NaN
#
# [6562 rows x 33 columns]

# %%
df = pd.read_csv("combined_df_final_nospace.csv", sep=";").drop_duplicates(subset="song_id")

# %%
df.head()
# Out:
#       original_song_name  original_artists_name  curr_rank tag_fimi publisher  \
# 0  svegliarsi la mattina          zero assoluto          1      sgo       NaN
# 1                    one     mary j. blige & u2          2      uni       NaN
# 2         sei nell'anima         gianna nannini          3      uni       NaN
# 3            upside down           jack johnson          4      uni       NaN
# 4        dani california  red hot chili peppers          5      wmi       NaN
#
#    date_chart album_release_date   album_type              song_name  \
# 0  07.05.2006         2006-02-28       single  Svegliarsi la mattina
# 1  07.05.2006         2021-06-10  compilation       One - Radio Edit
# 2  07.05.2006         2006-11-27        album         Sei nell'anima
# 3  07.05.2006               2006        album            Upside Down
# 4  07.05.2006         2006-04-03       single        Dani California
#
#                  album_id  ... liveness valence    tempo            type  \
# 0  6d1AvZ3brZ9caD2cFbIbbd  ...   0.0737   0.607  171.970  audio_features
# 1  1JTnevVl46CyP8Zj1rcUX4  ...   0.3780   0.262  185.908  audio_features
# 2  2htq51kTRL2dwMxa2mBfJi  ...   0.0834   0.468   91.010  audio_features
# 3  0kYv61g7n6ZPe2TVaIBeeJ  ...   0.1630   0.647  102.476  audio_features
# 4  3rrvHWzZCF8TvqT9oJtfVZ  ...   0.3460   0.730   96.184  audio_features
#
#                        id                                                uri  \
# 0  1ecMdfIXNksJTymYlzsFZ3  https://api.spotify.com/v1/tracks/1ecMdfIXNksJ...
# 1  7xtCBkcqlum3X6l7bN3tza               spotify:track:7xtCBkcqlum3X6l7bN3tza
# 2  6shzlUkm7OcnoO4guEiGJ8  https://api.spotify.com/v1/tracks/6shzlUkm7Ocn...
# 3  3YOigAKOgFTQuLjF9MBmd3  https://api.spotify.com/v1/tracks/3YOigAKOgFTQ...
# 4  6vODhpvfWwdsO0i9MBWnEq  https://api.spotify.com/v1/tracks/6vODhpvfWwds...
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/audio-analysis/1ecM...
# 1  https://api.spotify.com/v1/tracks/7xtCBkcqlum3...
# 2  https://api.spotify.com/v1/audio-analysis/6shz...
# 3  https://api.spotify.com/v1/audio-analysis/3YOi...
# 4  https://api.spotify.com/v1/audio-analysis/6vOD...
#
#                                         analysis_url  duration_ms  \
# 0                                             223053          4.0
# 1  https://api.spotify.com/v1/audio-analysis/7xtC...     243627.0
# 2                                             270347          4.0
# 3                                             208653          4.0
# 4                                             282160          4.0
#
#    time_signature
# 0             NaN
# 1             4.0
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 34 columns]

# %%
df.shape
# Out:
# (6563, 34)

# %%
song_unique = df[['id', 'tag_fimi',
       'publisher', 'album_release_date', 'album_type',
       'song_name', 'album_id', 'artists_names', 'artists_id', 'explicit',
       'duration', 'popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'type',
     'duration_ms']]

# %%
song_unique.head()
# Out:
#                        id tag_fimi publisher album_release_date   album_type  \
# 0  1ecMdfIXNksJTymYlzsFZ3      sgo       NaN         2006-02-28       single
# 1  7xtCBkcqlum3X6l7bN3tza      uni       NaN         2021-06-10  compilation
# 2  6shzlUkm7OcnoO4guEiGJ8      uni       NaN         2006-11-27        album
# 3  3YOigAKOgFTQuLjF9MBmd3      uni       NaN               2006        album
# 4  6vODhpvfWwdsO0i9MBWnEq      wmi       NaN         2006-04-03       single
#
#                song_name                album_id              artists_names  \
# 0  Svegliarsi la mattina  6d1AvZ3brZ9caD2cFbIbbd          ['Zero Assoluto']
# 1       One - Radio Edit  1JTnevVl46CyP8Zj1rcUX4    ['Mary J. Blige', 'U2']
# 2         Sei nell'anima  2htq51kTRL2dwMxa2mBfJi         ['Gianna Nannini']
# 3            Upside Down  0kYv61g7n6ZPe2TVaIBeeJ           ['Jack Johnson']
# 4        Dani California  3rrvHWzZCF8TvqT9oJtfVZ  ['Red Hot Chili Peppers']
#
#                                           artists_id explicit  ...  loudness  \
# 0                         ['3bf7Y2it29DeOjXpIibCOe']    False  ...    -9.350
# 1  ['1XkoF8ryArs86LZvFOkbyr', '51Blml2LZPmy7TTiAg...    False  ...    -2.595
# 2                         ['0h0p7RkMjCUMdcf0nXmHjX']    False  ...    -5.704
# 3                         ['3GBPw9NK25X1Wt2OUvOwY3']    False  ...    -8.299
# 4                         ['0L8ExT028jH3ddEcZwqJJ5']    False  ...    -2.360
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0   1.0       0.0423        0.1810          0.000458    0.0737    0.607
# 1   1.0       0.0813        0.1880          0.000000    0.3780    0.262
# 2   1.0       0.0216        0.4040          0.000002    0.0834    0.468
# 3   0.0       0.0433        0.2280          0.000128    0.1630    0.647
# 4   1.0       0.0437        0.0193          0.000009    0.3460    0.730
#
#      tempo            type  duration_ms
# 0  171.970  audio_features          4.0
# 1  185.908  audio_features     243627.0
# 2   91.010  audio_features          4.0
# 3  102.476  audio_features          4.0
# 4   96.184  audio_features          4.0
#
# [5 rows x 25 columns]

# %%
song_unique.to_csv("unique_songs_with_feats_6.csv",index=False, sep=";")

# %%
artists = df.drop_duplicates(subset="artists_names")["artists_names"].to_list()
out = []
for artist in artists:
    try:
        out.extend(eval(artist))
    except:
        out.append(artist)
#reg = re.compile(r",.+")
out_filtered = set([i for i in out])

# %%
pd.DataFrame(out_filtered, columns = ["artists_names"]).to_csv("unique_artists_6.csv",index=False)

# %%
import re
import pandas as pd

# %%
wiki = pd.read_csv("data/wikipages_it.csv", sep=";")

# %%
wikieng = pd.read_csv("data/wikipages_eng.csv", sep=";")

# %%
pd.merge(wiki,wikieng,on="spotyname", how="outer").to_csv("wikipages_eng_it_finale.csv",index=False, sep=";")

# %%
finalarts = pd.read_csv("data/pages/unique_artists_FINALISSIMISSIMO_2006_2021.csv", sep=";")

# %%
dwnpages = pd.read_csv("data/pages/wikipages_eng_it_full.csv",sep=";")

# %%
dwnpages.describe
# Out:
# <bound method NDFrame.describe of              spotyname            wikipagename           wikipagename_eng
# 0          Brunori Sas             Brunori Sas                Brunori Sas
# 1            Side Baby                     NaN                  Side Baby
# 2     Michael Marshall  Michael Marshall Smith  Michael Marshall (singer)
# 3     Michael Kiwanuka        Michael Kiwanuka           Michael Kiwanuka
# 4               Fergie                  Fergie            Fergie (singer)
# ...                ...                     ...                        ...
# 1959      Milky Chance            Milky Chance               Milky Chance
# 1960        Maty Noyes              Maty Noyes                 Maty Noyes
# 1961         21 Savage               21 Savage                  21 Savage
# 1962     David Gilmour           David Gilmour              David Gilmour
# 1963         Tom Jones    Tom Jones (cantante)         Tom Jones (singer)
#
# [1964 rows x 3 columns]>

# %%
finalarts.describe
# Out:
# <bound method NDFrame.describe of               spotyname
# 0            cmqmartina
# 1     Children Of Bodom
# 2               Ward 21
# 3              Maroon 5
# 4             Rammstein
# ...                 ...
# 2424       Samuel Storm
# 2425  Cast Of Camp Rock
# 2426              JAY-Z
# 2427              Jaden
# 2428      La Differenza
#
# [2429 rows x 1 columns]>

# %%
inter = dwnpages.merge(finalarts, how = 'outer')

# %%
inter.describe
# Out:
# <bound method NDFrame.describe of                spotyname            wikipagename           wikipagename_eng
# 0            Brunori Sas             Brunori Sas                Brunori Sas
# 1              Side Baby                     NaN                  Side Baby
# 2       Michael Marshall  Michael Marshall Smith  Michael Marshall (singer)
# 3       Michael Kiwanuka        Michael Kiwanuka           Michael Kiwanuka
# 4                 Fergie                  Fergie            Fergie (singer)
# ...                  ...                     ...                        ...
# 2436      Enrico Musiani                     NaN                        NaN
# 2437               Nabat                     NaN                        NaN
# 2438                ANNA                     NaN                        NaN
# 2439  Axwell /\ Ingrosso                     NaN                        NaN
# 2440               Morad                     NaN                        NaN
#
# [2441 rows x 3 columns]>

# %%
inter.merge(finalarts, how="inner").to_csv("wikipages_eng_it_complete.csv",index=False, sep=";")
